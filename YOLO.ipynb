# %%
pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/877.6 kB ? eta -:--:--
#    ---------------------------------------- 877.6/877.6 kB 7.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.6 MB 4.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.6 MB 3.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.6/11.6 MB 3.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.1/11.6 MB 3.8 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.6 MB 3.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.6 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 5.5/11.6 MB 3.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 6.6/11.6 MB 3.9 MB/s eta 0:00:02
#    ------------------------- -------------- 7.3/11.6 MB 3.9 MB/s eta 0:00:02
# ...

# %%
from ultralytics import YOLO

model = YOLO('models/best.pt')

results = model.predict('TRY.mp4', save=True)
print(results[0])
print('')
for box in results[0].boxes:
    print(box)
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Asus\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# ...

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      2.1.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# attrs                        24.2.0
# certifi                      2024.8.30
# cffi                         1.17.1
# charset-normalizer           3.4.0
# click                        8.1.7
# colorama                     0.4.6
# comm                         0.2.2
# comtypes                     1.4.7
# contourpy                    1.3.0
# cycler                       0.12.1
# DateTime                     5.5
# debugpy                      1.8.7
# decorator                    5.1.1
# executing                    2.1.0
# flatbuffers                  24.3.25
# fonttools                    4.54.1
# gast                         0.6.0
# google-pasta                 0.2.0
# grpcio                       1.67.0
# gTTS                         2.5.3
# h5py                         3.12.1
# ...
